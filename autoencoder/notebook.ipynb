# %%
from main_runner import *

# %%
a = torch.tensor([[-30.0, 10.0]], device = "mps")
b = torch.tensor([[-10.0, 10.0]], device = "mps")

# %%
A = decode_model(b)
px.imshow(A.cpu().detach().numpy()[0, 0, :, :])
